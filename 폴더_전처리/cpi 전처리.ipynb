# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import matplotlib.font_manager as fm

plt.rcParams['font.family'] = 'NanumGothic'
plt.style.use('ggplot')

# %%
os.chdir('C:\\Users\\user\\OneDrive\\바탕 화면\\이현방\\빅콘테스트\\Seafood_Import_Price_Prediction\\DATA')

# %%
root = os.path.join(os.getcwd(), 'cpi')

# %%
cpi_region = pd.read_excel(os.path.join(root, 'raw_cpi_region.xlsx')) # 전국 소비자지수

cpi_region
# Out:
# C:\Users\user\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    시도별(1)   시도별(2) 품목별(1)  2015. 12  2016. 01  2016. 02  2016. 03  2016. 04  \
# 0      전국       소계    총지수    100.22    100.39    100.82    100.56    100.75
# 1     NaN    서울특별시    총지수    100.55    100.63    101.03    100.71    100.88
# 2     NaN    부산광역시    총지수    100.14    100.34    101.12    100.86    101.09
# 3     NaN    대구광역시    총지수    100.16    100.27    100.68    100.55    100.78
# 4     NaN    인천광역시    총지수    100.17    100.45    100.78    100.49    100.69
# 5     NaN    광주광역시    총지수    100.05    100.11    100.59    100.41    100.58
# 6     NaN    대전광역시    총지수    100.31    100.42    100.77    100.41    100.50
# 7     NaN    울산광역시    총지수    100.15    100.47    100.77    100.48    100.65
# ...

# %%
cpi_region.drop(['시도별(2)','품목별(1)'],inplace=True,axis=1) # 열 삭제

cpi_region = cpi_region[cpi_region['시도별(1)']=='전국'] # 전국 소비자지수 데이터만 추출

cpi_region2 = pd.DataFrame(cpi_region.values.reshape(50,1),index=cpi_region.columns,columns=['CPI'])

cpi_region2.drop('시도별(1)',axis=0,inplace=True)

cpi_region2 # 컬럼 인덱스 순서 변경
# Out:
#              CPI
# 2015. 12  100.22
# 2016. 01  100.39
# 2016. 02  100.82
# 2016. 03  100.56
# 2016. 04  100.75
# 2016. 05  100.81
# 2016. 06  100.79
# 2016. 07   100.6
# 2016. 08  100.86
# 2016. 09  101.46
# 2016. 10   101.6
# 2016. 11  101.45
# 2016. 12  101.56
# 2017. 01  102.64
# 2017. 02  102.92
# 2017. 03  102.85
# 2017. 04  102.72
# 2017. 05  102.83
# 2017. 06  102.61
# 2017. 07  102.78
# 2017. 08  103.37
# 2017. 09  103.49
# 2017. 10  103.39
# 2017. 11  102.62
# 2017. 12  102.99
# 2018. 01  103.42
# 2018. 02  104.21
# 2018. 03   104.1
# 2018. 04  104.29
# 2018. 05  104.34
# 2018. 06  104.13
# 2018. 07  103.93
# 2018. 08  104.85
# 2018. 09  105.65
# 2018. 10  105.46
# 2018. 11  104.71
# 2018. 12  104.35
# 2019. 01  104.24
# 2019. 02  104.69
# 2019. 03  104.49
# 2019. 04  104.87
# 2019. 05  105.05
# 2019. 06  104.88
# 2019. 07  104.56
# 2019. 08  104.81
# 2019. 09   105.2
# 2019. 10  105.46
# 2019. 11  104.87
# 2019. 12  105.12

# %%
cpi_region2.to_csv("C:\\Users\\user\\OneDrive\\바탕 화면\\cpi_region2.csv")

# %%
cpi_purpose = pd.read_csv(os.path.join(root, 'raw_cpi_purpose.csv'),encoding='ANSI') # 전국 품종별 소비자지수

cpi_purpose = pd.DataFrame(cpi_purpose)

cpi_purpose
# Out:
#    시도별                지출목적별  2015. 12  2016. 01  2016. 02  2016. 03  2016. 04  \
# 0   전국                0 총지수    100.22    100.39    100.82    100.56    100.75
# 1   전국       01 식료품 · 비주류음료     99.95    100.76    103.43    102.25    102.30
# 2   전국           02 주류 및 담배    100.31    100.49    100.65    100.67    100.73
# 3   전국           03 의류 및 신발    101.38    100.74    101.51    101.51    101.55
# 4   전국  04 주택 ·수도 · 전기 및 연료    100.75     99.97    100.29     99.55     99.60
# 5   전국     05 가정용품 및 가사 서비스    100.74    100.91    101.27    101.73    101.29
# 6   전국                06 보건    100.00    100.99    100.94    100.93    100.99
# 7   전국                07 교통     98.38     97.68     96.16     95.71     96.12
# 8   전국                08 통신     99.61     99.27     99.27     99.27    100.42
# 9   전국           09 오락 및 문화     99.82    100.08    100.77    100.35    100.72
# 10  전국                10 교육    100.44    100.86    101.09    101.42    101.54
# ...

# %%
cpi_purpose = cpi_purpose.iloc[[1,11],:]

cpi_purpose.drop('시도별',axis=1,inplace=True) # 시도별 칼럼 제거

cpi_purpose # 전국 식료품별, 음식서비스별 cpi만 추출
# Out:
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\frame.py:4901: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#              지출목적별  2015. 12  2016. 01  2016. 02  2016. 03  2016. 04  \
# 1   01 식료품 · 비주류음료     99.95    100.76    103.43    102.25    102.30
# 11      11 음식 및 숙박    101.06    101.40    101.67    101.98    102.26
#
#     2016. 05  2016. 06  2016. 07  2016. 08  ...  2020. 09  2020. 10  2020. 11  \
# 1     101.24     99.66     99.65    101.02  ...    119.68    119.82    115.35
# 11    102.40    102.50    102.74    102.91  ...    111.25    111.51    111.41
#
#     2020. 12  2021. 01  2021. 02  2021. 03  2021. 04  2021. 05  2021. 06
# 1     115.79    118.04    120.97    120.61    120.34    119.70    118.43
# ...

# %%
cpi_purpose2 = pd.DataFrame(cpi_purpose.iloc[0,:].values,index = cpi_purpose.columns,columns=['식료품 cpi'])

cpi_purpose2['음식 및 숙박 cpi'] = cpi_purpose.iloc[1,:].values

cpi_purpose2.drop('지출목적별',axis=0,inplace=True) # 지출목적별 행 삭제

cpi_purpose2 # 식료품, 음식 cpi
# Out:
#          식료품 cpi 음식 및 숙박 cpi
# 2015. 12   99.95      101.06
# 2016. 01  100.76       101.4
# 2016. 02  103.43      101.67
# 2016. 03  102.25      101.98
# 2016. 04   102.3      102.26
# ...          ...         ...
# 2021. 02  120.97      112.26
# 2021. 03  120.61      112.42
# 2021. 04  120.34      112.93
# 2021. 05   119.7      113.11
# 2021. 06  118.43      113.37
#
# [67 rows x 2 columns]

# %%
cpi_purpose2.to_csv("C:\\Users\\user\\OneDrive\\바탕 화면\\cpi_purpose2.csv")
